# %%
import pandas as pd 
import requests
import json
from datetime import datetime
import datetime

# %%
USER_ID = "Anshuman Upadhyay"
TOKEN = "BQD1pjKtT7RJ7f1cP1yuC6TpxCJWIa82r5S6qRsscmlICD-1JIpRHktQTbC6__3nZQ7KiOGUxEQah6wncOkJSlRrgibBXAIK5tf6L7397n3_kBlhX-YCosCQnzd0n6VGsalOdGG54-aXWYZUNoMe_om1ALnPTyEZWWWOAlNC"

if __name__ == "__main__":

    # Extract part of the ETL process
 
    headers = {
        "Accept" : "application/json",
        "Content-Type" : "application/json",
        "Authorization" : "Bearer {token}".format(token=TOKEN)
    }
    
    # Convert time to Unix timestamp in miliseconds      
    today = datetime.datetime.now()
    yesterday = today - datetime.timedelta(days=2)
    yesterday_unix_timestamp = int(yesterday.timestamp()) * 1000

    # Download all songs you've listened to "after yesterday", which means in the last 24 hours      
    r = requests.get("https://api.spotify.com/v1/me/player/recently-played?after={time}".format(time=yesterday_unix_timestamp), headers = headers)

    data = r.json()
    print(data)
# Out:
# {'items': [{'track': {'album': {'album_type': 'album', 'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1Xyo4u8uXC1ZmMpatF05PJ'}, 'href': 'https://api.spotify.com/v1/artists/1Xyo4u8uXC1ZmMpatF05PJ', 'id': '1Xyo4u8uXC1ZmMpatF05PJ', 'name': 'The Weeknd', 'type': 'artist', 'uri': 'spotify:artist:1Xyo4u8uXC1ZmMpatF05PJ'}], 'available_markets': ['AD', 'AE', 'AG', 'AL', 'AM', 'AO', 'AR', 'AT', 'AU', 'AZ', 'BA', 'BB', 'BD', 'BE', 'BG', 'BH', 'BI', 'BJ', 'BO', 'BR', 'BS', 'BT', 'BW', 'BZ', 'CA', 'CH', 'CI', 'CL', 'CM', 'CO', 'CR', 'CV', 'CW', 'CY', 'CZ', 'DE', 'DJ', 'DK', 'DM', 'DO', 'DZ', 'EC', 'EE', 'EG', 'ES', 'FI', 'FJ', 'FM', 'FR', 'GA', 'GB', 'GD', 'GE', 'GH', 'GM', 'GN', 'GQ', 'GR', 'GT', 'GW', 'GY', 'HK', 'HN', 'HR', 'HT', 'HU', 'ID', 'IE', 'IL', 'IN', 'IS', 'IT', 'JM', 'JO', 'JP', 'KE', 'KG', 'KH', 'KI', 'KM', 'KN', 'KR', 'KW', 'KZ', 'LA', 'LB', 'LC', 'LI', 'LK', 'LR', 'LS', 'LT', 'LU', 'LV', 'MA', 'MC', 'MD', 'ME', 'MG', 'MH', 'MK', 'ML', 'MN', 'MO', 'MR',
# ...

# %%
    song_names = []
    artist_names = []
    played_at_list = []
    timestamps = []

    # Extracting only the relevant bits of data from the json object      
    for song in data["items"]:
        song_names.append(song["track"]["name"])
        artist_names.append(song["track"]["album"]["artists"][0]["name"])
        played_at_list.append(song["played_at"])
        timestamps.append(song["played_at"][0:10])
        
    # Prepare a dictionary in order to turn it into a pandas dataframe below       
    song_dict = {
        "song_name" : song_names,
        "artist_name": artist_names,
        "played_at" : played_at_list,
        "timestamp" : timestamps
    }

    song_df = pd.DataFrame(song_dict, columns = ["song_name", "artist_name", "played_at", "timestamp"])

# %%
song_df
# Out:
#                                        song_name         artist_name  \
# 0                                        Starboy          The Weeknd
# 1                                         Wonder        Shawn Mendes
# 2                                   Cruel Summer        Taylor Swift
# 3                                   Cruel Summer        Taylor Swift
# 4                                   Cruel Summer        Taylor Swift
# 5                                           2055       Sleepy Hallow
# 6          Summer of Love (Shawn Mendes & Tainy)        Shawn Mendes
# 7   Save Your Tears (with Ariana Grande) (Remix)          The Weeknd
# 8                          Sooraj Ki Baahon Mein  Shankar-Ehsaan-Loy
# 9                                       Hey Ya !  Shankar-Ehsaan-Loy
# 10                                  Baat Bangayi               Rawal
# 11                                      Crawling         Linkin Park
# 12                                      Crawling         Linkin Park
# ...

# %%
def check_if_valid(df):
    if df.empty:
        print("No songs downloaded")
        return false
    
    if df['played_at'].is_unique:
        pass
    else:
        raise Exception("Pk check is violated")
    
    if df.isnull().values.any():
        raise Exception("Null values found")
    return True

# %%
if check_if_valid(song_df):
        print("Data valid, proceed to Load stage")
# Out:
# Data valid, proceed to Load stage

# %%
import psycopg2

# %%
conn = psycopg2.connect("host=localhost dbname=postgres user=postgres password=rikin0305")
cur = conn.cursor()

# %%
conn.set_session(autocommit=True)

# %%
cur.execute("CREATE DATABASE projects")

# %%
cur.close()
conn.close()

# %%
conn = psycopg2.connect("host=localhost dbname=projects user=postgres password=rikin0305")
cur = conn.cursor()

# %%
conn.set_session(autocommit=True)

# %%
cur.execute("CREATE TABLE my_tracks (Song_name varchar, Artist_name varchar, Played_at varchar, Timestamp date);")

# %%
for i, row in song_df.iterrows():
    cur.execute("INSERT INTO my_tracks (Song_name, Artist_name, Played_at, Timestamp) VALUES(%s, %s, %s, %s)",list(row))

# %%
cur.close()
conn.close()
